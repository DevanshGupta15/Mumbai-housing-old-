# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
sns.set_style("darkgrid")
plt.rcParams['font.size'] = 14
plt.rcParams['figure.figsize'] = (9, 5)
plt.rcParams['figure.facecolor'] = '#00000000'

# %%
df = pd.read_csv("mumbai.csv")

# %%
df.head()
# Out:
#         price                                            Address    area  \
# 0  22400000.0        Chembur, Mumbai - Harbour Line, Maharashtra   629.0
# 1  35000000.0        Chembur, Mumbai - Harbour Line, Maharashtra   974.0
# 2  31700000.0  Ghatkopar East, Mumbai - Central Line, Maharas...   968.0
# 3  18700000.0  Plot Number 283, Road Number 3, Jawahar Nagar,...   629.0
# 4  13500000.0  malad east, Malad East, Mumbai - North Mumbai,...  1090.0
#
#     latitude  longitude  Bedrooms  Bathrooms  Balcony              Status  \
# 0  19.032800  72.896357       2.0        2.0      NaN  Under Construction
# 1  19.032800  72.896357       3.0        2.0      NaN  Under Construction
# 2  19.085600  72.909277       3.0        3.0      NaN  Under Construction
# 3  19.155756  72.846862       2.0        2.0      2.0       Ready to Move
# 4  19.177555  72.849887       2.0        2.0      NaN                 NaN
#
#        neworold  parking Furnished_status  Lift               Landmarks  \
# ...

# %%
df.sample(5)
# Out:
#            price                                            Address    area  \
# 3355  22500000.0    Mulund West, Mumbai - Central Line, Maharashtra   971.0
# 4184   5000000.0  Virar West, Mumbai - Mira Road and Beyond, Mah...  1050.0
# 3784  10000000.0   Tagore Nagar, Mumbai - Central Line, Maharashtra  1200.0
# 828   13000000.0        Charkop, Mumbai - North Mumbai, Maharashtra   585.0
# 4744  13000000.0  Goregaon East, Mumbai - Western Suburbs, Mahar...   850.0
#
#        latitude  longitude  Bedrooms  Bathrooms  Balcony         Status  \
# 3355  19.174674  72.943104       2.0        2.0      2.0  Ready to Move
# 4184  19.454059  72.768823       3.0        2.0      NaN  Ready to Move
# 3784  19.116230  72.932050       2.0        2.0      NaN  Ready to Move
# 828   19.210045  72.818349       2.0        2.0      NaN  Ready to Move
# 4744  19.178186  72.863518       2.0        2.0      NaN  Ready to Move
#
#      neworold  parking Furnished_status  Lift Landmarks type_of_building  \
# ...

# %%
df.shape
# Out:
# (6255, 17)

# %%
df.columns
# Out:
# Index(['price', 'Address', 'area', 'latitude', 'longitude', 'Bedrooms',
#        'Bathrooms', 'Balcony', 'Status', 'neworold', 'parking',
#        'Furnished_status', 'Lift', 'Landmarks', 'type_of_building', 'desc',
#        'Price_sqft'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# price                  0
# Address                0
# area                   0
# latitude               0
# longitude              0
# Bedrooms               0
# Bathrooms              0
# Balcony             3879
# Status               481
# neworold               0
# parking             4126
# Furnished_status    2655
# Lift                4577
# Landmarks           3638
# type_of_building       0
# desc                   0
# Price_sqft             0
# dtype: int64

# %%
df.Lift.unique()
# Out:
# array([ 2.,  3.,  5.,  6.,  4., nan,  8.,  1.,  7.,  0., 10.,  9.])

# %%
df.Lift.value_counts()
# Out:
# 2.0     758
# 1.0     327
# 3.0     220
# 4.0     174
# 0.0      55
# 5.0      51
# 6.0      49
# 7.0      18
# 8.0      11
# 10.0     11
# 9.0       4
# Name: Lift, dtype: int64

# %%
df.neworold.unique()
# Out:
# array(['New Property', 'Resale'], dtype=object)

# %%
df2 = df.drop(columns=["latitude","longitude","Balcony","Furnished_status","Lift","Landmarks","desc","parking"],axis=1)

# %%
df2.shape
# Out:
# (6255, 9)

# %%
df2.head()
# Out:
#         price                                            Address    area  \
# 0  22400000.0        Chembur, Mumbai - Harbour Line, Maharashtra   629.0
# 1  35000000.0        Chembur, Mumbai - Harbour Line, Maharashtra   974.0
# 2  31700000.0  Ghatkopar East, Mumbai - Central Line, Maharas...   968.0
# 3  18700000.0  Plot Number 283, Road Number 3, Jawahar Nagar,...   629.0
# 4  13500000.0  malad east, Malad East, Mumbai - North Mumbai,...  1090.0
#
#    Bedrooms  Bathrooms              Status      neworold type_of_building  \
# 0       2.0        2.0  Under Construction  New Property             Flat
# 1       3.0        2.0  Under Construction  New Property             Flat
# 2       3.0        3.0  Under Construction  New Property             Flat
# 3       2.0        2.0       Ready to Move  New Property             Flat
# 4       2.0        2.0                 NaN  New Property             Flat
#
#      Price_sqft
# 0  35612.082671
# 1  35934.291581
# 2  32747.933884
# ...

# %%
df2.isnull().sum()
# Out:
# price                 0
# Address               0
# area                  0
# Bedrooms              0
# Bathrooms             0
# Status              481
# neworold              0
# type_of_building      0
# Price_sqft            0
# dtype: int64

# %%
df2.Status.unique()
# Out:
# array(['Under Construction', 'Ready to Move', nan], dtype=object)

# %%
df3 = df2.dropna()

# %%
df3.shape
# Out:
# (5774, 9)

# %%
df3.isnull().sum()
# Out:
# price               0
# Address             0
# area                0
# Bedrooms            0
# Bathrooms           0
# Status              0
# neworold            0
# type_of_building    0
# Price_sqft          0
# dtype: int64

# %%
df3.head()
# Out:
#         price                                            Address    area  \
# 0  22400000.0        Chembur, Mumbai - Harbour Line, Maharashtra   629.0
# 1  35000000.0        Chembur, Mumbai - Harbour Line, Maharashtra   974.0
# 2  31700000.0  Ghatkopar East, Mumbai - Central Line, Maharas...   968.0
# 3  18700000.0  Plot Number 283, Road Number 3, Jawahar Nagar,...   629.0
# 9  81000000.0  Worli, Mumbai, Worli, Mumbai - South Mumbai, M...  3260.0
#
#    Bedrooms  Bathrooms              Status      neworold type_of_building  \
# 0       2.0        2.0  Under Construction  New Property             Flat
# 1       3.0        2.0  Under Construction  New Property             Flat
# 2       3.0        3.0  Under Construction  New Property             Flat
# 3       2.0        2.0       Ready to Move  New Property             Flat
# 9       3.0        3.0       Ready to Move        Resale             Flat
#
#      Price_sqft
# 0  35612.082671
# 1  35934.291581
# 2  32747.933884
# ...

# %%
df3.Bedrooms.unique()
# Out:
# array([ 2.,  3.,  4.,  6.,  5.,  8.,  7., 10.])

# %%
df3.Bedrooms.value_counts()
# Out:
# 2.0     3777
# 3.0     1540
# 4.0      341
# 5.0       75
# 6.0       25
# 7.0        9
# 8.0        4
# 10.0       3
# Name: Bedrooms, dtype: int64

# %%
df3.Bathrooms.unique()
# Out:
# array([ 2.,  3.,  4.,  5.,  6.,  7.,  8., 10.,  0.])

# %%
df3.Bathrooms.value_counts()
# Out:
# 2.0     4011
# 3.0     1265
# 4.0      355
# 5.0      101
# 6.0       30
# 7.0        5
# 8.0        5
# 10.0       1
# 0.0        1
# Name: Bathrooms, dtype: int64

# %%
plt.plot(df3.Bathrooms)

# %%
df3[df3.Bathrooms>8]
# Out:
#            price                                           Address   area  \
# 2994  80000000.0  Khar East, Mumbai - Western Suburbs, Maharashtra  816.0
#
#       Bedrooms  Bathrooms         Status neworold type_of_building  \
# 2994      10.0       10.0  Ready to Move   Resale             Flat
#
#         Price_sqft
# 2994  98039.215686

# %%
df3.loc[2994]
# Out:
# price                                                     80000000.0
# Address             Khar East, Mumbai - Western Suburbs, Maharashtra
# area                                                           816.0
# Bedrooms                                                        10.0
# Bathrooms                                                       10.0
# Status                                                 Ready to Move
# neworold                                                      Resale
# type_of_building                                                Flat
# Price_sqft                                              98039.215686
# Name: 2994, dtype: object

# %%
df4 = df3.copy()

# %%
df4 = df4.drop(2994)

# %%
df4.Bathrooms.value_counts()
# Out:
# 2.0    4011
# 3.0    1265
# 4.0     355
# 5.0     101
# 6.0      30
# 7.0       5
# 8.0       5
# 0.0       1
# Name: Bathrooms, dtype: int64

# %%
df4[df4.Bathrooms==0]
# Out:
#            price                                            Address   area  \
# 3021  12000000.0  Mumbai-Western Suburbs, Kandivali West, Mumbai...  812.0
#
#       Bedrooms  Bathrooms         Status neworold type_of_building  \
# 3021       2.0        0.0  Ready to Move   Resale             Flat
#
#         Price_sqft
# 3021  14778.325123

# %%
df4.loc[3084]
# Out:
# price                                                     9000000.0
# Address             Ulhasnagar, Mumbai - Around Mumbai, Maharashtra
# area                                                         1200.0
# Bedrooms                                                        8.0
# Bathrooms                                                       8.0
# Status                                                Ready to Move
# neworold                                                     Resale
# type_of_building                                   Individual House
# Price_sqft                                                   7500.0
# Name: 3084, dtype: object

# %%
df5 = df4.copy()
df5 = df5.drop(3084)

# %%
sns.countplot(df5.neworold)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='neworold', ylabel='count'>

# %%
sns.countplot(df5.type_of_building)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='type_of_building', ylabel='count'>

# %%
sns.countplot(df5.Status)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Status', ylabel='count'>

# %%
len(df5.Address.unique())
# Out:
# 3419

# %%
df5.Address = df5.Address.apply(lambda x : x.strip(" "))

# %%
Address_stats = df5.groupby("Address")['Address'].agg('count')

# %%
Address_stats.sort_values(ascending=False)
# Out:
# Address
# Mira Road, Mumbai - Mira Road and Beyond, Maharashtra                                                                                                                        147
# Andheri West, Mumbai - Western Suburbs, Maharashtra                                                                                                                          125
# Andheri East, Mumbai - Western Suburbs, Maharashtra                                                                                                                           75
# Chembur, Mumbai - Harbour Line, Maharashtra                                                                                                                                   74
# Kandivali West, Mumbai - North Mumbai, Maharashtra                                                                                                                            67
# ...

# %%
len(Address_stats[Address_stats<=5])
# Out:
# 3318

# %%
Address_less_than_five = Address_stats[Address_stats<=5]
Address_less_than_five
# Out:
# Address
# ----., Thane-Kalyan-Dombivli, Mumbai, Maharashtra                                                                                                   1
# 001, Ground Floor, Mahavir Aquila, Plot No. 163-B Derasar Lane Ghatkopar (East) Mumbai 400 077, Derasar Lane, Mumbai - Central Line, Maharashtra    1
# 001., Kandivali West, Mumbai - North Mumbai, Maharashtra                                                                                            1
# 001., Lallu Bhai Park, Mumbai - Western Suburbs, Maharashtra                                                                                        1
# 001., Mulund East, Mumbai - Central Line, Maharashtra                                                                                               1
#                                                                                                                                                    ..
# ...

# %%
len(df5.Address.unique())
# Out:
# 3419

# %%
df5.Address = df5.Address.apply(lambda x : "others" if x in Address_less_than_five else x)

# %%
len(df5.Address.unique())
# Out:
# 102

# %%
df5.head(2)
# Out:
#         price                                      Address   area  Bedrooms  \
# 0  22400000.0  Chembur, Mumbai - Harbour Line, Maharashtra  629.0       2.0
# 1  35000000.0  Chembur, Mumbai - Harbour Line, Maharashtra  974.0       3.0
#
#    Bathrooms              Status      neworold type_of_building    Price_sqft
# 0        2.0  Under Construction  New Property             Flat  35612.082671
# 1        2.0  Under Construction  New Property             Flat  35934.291581

# %%
df5[df5.area/df5.Bedrooms<200].head()
# Out:
#            price                                           Address   area  \
# 957   10500000.0                                            others  660.0
# 1186  12500000.0  Dahisar East, Mumbai - North Mumbai, Maharashtra  570.0
# 2638  15000000.0   Mulund West, Mumbai - Central Line, Maharashtra  516.0
#
#       Bedrooms  Bathrooms         Status neworold  type_of_building  \
# 957        6.0        2.0  Ready to Move   Resale  Individual House
# 1186       3.0        2.0  Ready to Move   Resale              Flat
# 2638       3.0        3.0  Ready to Move   Resale              Flat
#
#         Price_sqft
# 957   15909.090909
# 1186  21929.824561
# 2638  29069.767442

# %%
df5.shape

# %%
df6 = df5[~(df5.area/df5.Bedrooms<200)]
df6.shape
# Out:
# (5769, 9)

# %%
df5.Price_sqft.describe()
# Out:
# count      5772.000000
# mean      21506.331068
# std       12799.214175
# min        1500.000000
# 25%       13750.000000
# 50%       19395.966352
# 75%       26562.500000
# max      119047.619048
# Name: Price_sqft, dtype: float64

# %%
dummies = pd.get_dummies(df5.Address)
dummies.head()
# Out:
#    Agripada, Mumbai - South Mumbai, Maharashtra  \
# 0                                             0
# 1                                             0
# 2                                             0
# 3                                             0
# 9                                             0
#
#    Ambernath, Mumbai, Maharashtra  \
# 0                               0
# 1                               0
# 2                               0
# 3                               0
# 9                               0
#
#    Andheri East, Mumbai - Western Suburbs, Maharashtra  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 9                                                  0
#
#    Andheri East, Mumbai, Andheri East, Mumbai - Western Suburbs, Maharashtra  \
# 0                                                  0
# ...

# %%
df6 = pd.concat([df5,dummies.drop('others',axis='columns')],axis='columns')
df6.head()
# Out:
#         price                                            Address    area  \
# 0  22400000.0        Chembur, Mumbai - Harbour Line, Maharashtra   629.0
# 1  35000000.0        Chembur, Mumbai - Harbour Line, Maharashtra   974.0
# 2  31700000.0  Ghatkopar East, Mumbai - Central Line, Maharas...   968.0
# 3  18700000.0                                             others   629.0
# 9  81000000.0  Worli, Mumbai, Worli, Mumbai - South Mumbai, M...  3260.0
#
#    Bedrooms  Bathrooms              Status      neworold type_of_building  \
# 0       2.0        2.0  Under Construction  New Property             Flat
# 1       3.0        2.0  Under Construction  New Property             Flat
# 2       3.0        3.0  Under Construction  New Property             Flat
# 3       2.0        2.0       Ready to Move  New Property             Flat
# 9       3.0        3.0       Ready to Move        Resale             Flat
#
#      Price_sqft  Agripada, Mumbai - South Mumbai, Maharashtra  ...  \
# ...

# %%
df7= df6.drop(columns=["Address"],axis=1)

# %%
df7.head()
# Out:
#         price    area  Bedrooms  Bathrooms              Status      neworold  \
# 0  22400000.0   629.0       2.0        2.0  Under Construction  New Property
# 1  35000000.0   974.0       3.0        2.0  Under Construction  New Property
# 2  31700000.0   968.0       3.0        3.0  Under Construction  New Property
# 3  18700000.0   629.0       2.0        2.0       Ready to Move  New Property
# 9  81000000.0  3260.0       3.0        3.0       Ready to Move        Resale
#
#   type_of_building    Price_sqft  \
# 0             Flat  35612.082671
# 1             Flat  35934.291581
# 2             Flat  32747.933884
# 3             Flat  29729.729730
# 9             Flat  24846.625767
#
#    Agripada, Mumbai - South Mumbai, Maharashtra  \
# 0                                             0
# 1                                             0
# 2                                             0
# 3                                             0
# 9                                             0
#
# ...

# %%
from sklearn.preprocessing import LabelEncoder
Encoder = LabelEncoder()
df7["Status"] = Encoder.fit_transform(df7["Status"])
df7["neworold"] = Encoder.fit_transform(df7["neworold"])
df7["type_of_building"] = Encoder.fit_transform(df7["type_of_building"])

# %%
df7.head()
# Out:
#         price    area  Bedrooms  Bathrooms  Status  neworold  \
# 0  22400000.0   629.0       2.0        2.0       1         0
# 1  35000000.0   974.0       3.0        2.0       1         0
# 2  31700000.0   968.0       3.0        3.0       1         0
# 3  18700000.0   629.0       2.0        2.0       0         0
# 9  81000000.0  3260.0       3.0        3.0       0         1
#
#    type_of_building    Price_sqft  \
# 0                 0  35612.082671
# 1                 0  35934.291581
# 2                 0  32747.933884
# 3                 0  29729.729730
# 9                 0  24846.625767
#
#    Agripada, Mumbai - South Mumbai, Maharashtra  \
# 0                                             0
# 1                                             0
# 2                                             0
# 3                                             0
# 9                                             0
#
#    Ambernath, Mumbai, Maharashtra  ...  \
# 0                               0  ...
# ...

# %%
df7.drop(columns=["Status","neworold","type_of_building"],axis=1,inplace=True)

# %%
df7.head()
# Out:
#         price    area  Bedrooms  Bathrooms    Price_sqft  \
# 0  22400000.0   629.0       2.0        2.0  35612.082671
# 1  35000000.0   974.0       3.0        2.0  35934.291581
# 2  31700000.0   968.0       3.0        3.0  32747.933884
# 3  18700000.0   629.0       2.0        2.0  29729.729730
# 9  81000000.0  3260.0       3.0        3.0  24846.625767
#
#    Agripada, Mumbai - South Mumbai, Maharashtra  \
# 0                                             0
# 1                                             0
# 2                                             0
# 3                                             0
# 9                                             0
#
#    Ambernath, Mumbai, Maharashtra  \
# 0                               0
# 1                               0
# 2                               0
# 3                               0
# 9                               0
#
#    Andheri East, Mumbai - Western Suburbs, Maharashtra  \
# 0                                                  0
# ...

# %% [markdown]
# # BUILDING MODEL

# %%
X = df7.drop("price",axis=1)

# %%
y = df7["price"]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=10)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
model.score(X_test,y_test)
# Out:
# 0.8693625424992336

# %%
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import cross_val_score

cv = ShuffleSplit(n_splits=5, test_size=0.2, random_state=0)

cross_val_score(LinearRegression(), X, y, cv=cv)
# Out:
# array([0.8671014 , 0.88543121, 0.8927082 , 0.88693839, 0.86400322])

# %%
from sklearn.model_selection import GridSearchCV

from sklearn.linear_model import Lasso
from sklearn.tree import DecisionTreeRegressor

def find_best_model_using_gridsearchcv(X,y):
    algos = {
        'linear_regression' : {
            'model': LinearRegression(),
            'params': {
                'normalize': [True, False]
            }
        },
        'lasso': {
            'model': Lasso(),
            'params': {
                'alpha': [1,2],
                'selection': ['random', 'cyclic']
            }
        },
        'decision_tree': {
            'model': DecisionTreeRegressor(),
            'params': {
                'criterion' : ['mse','friedman_mse'],
                'splitter': ['best','random']
            }
        }
    }
    scores = []
    cv = ShuffleSplit(n_splits=5, test_size=0.2, random_state=0)
    for algo_name, config in algos.items():
        gs =  GridSearchCV(config['model'], config['params'], cv=cv, return_train_score=False)
        gs.fit(X,y)
        scores.append({
            'model': algo_name,
            'best_score': gs.best_score_,
            'best_params': gs.best_params_
        })

    return pd.DataFrame(scores,columns=['model','best_score','best_params'])

find_best_model_using_gridsearchcv(X,y)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LinearRegression())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
#
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# ...

# %%
def predict_price(Address,area,Bathrooms,Bedrooms):    
    loc_index = np.where(X.columns==Address)[0][0]

    x = np.zeros(len(X.columns))
    x[0] = area
    x[1] = Bathrooms
    x[2] = Bedrooms
    if loc_index >= 0:
        x[loc_index] = 1

    return model.predict([x])[0]

# %%
predict_price("Chembur, Mumbai - Harbour Line, Maharashtra",600,2,2)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# -19669254.812181294

# %%
df7.head()
# Out:
#         price    area  Bedrooms  Bathrooms  Status  neworold  \
# 0  22400000.0   629.0       2.0        2.0       1         0
# 1  35000000.0   974.0       3.0        2.0       1         0
# 2  31700000.0   968.0       3.0        3.0       1         0
# 3  18700000.0   629.0       2.0        2.0       0         0
# 9  81000000.0  3260.0       3.0        3.0       0         1
#
#    type_of_building    Price_sqft  \
# 0                 0  35612.082671
# 1                 0  35934.291581
# 2                 0  32747.933884
# 3                 0  29729.729730
# 9                 0  24846.625767
#
#    Agripada, Mumbai - South Mumbai, Maharashtra  \
# 0                                             0
# 1                                             0
# 2                                             0
# 3                                             0
# 9                                             0
#
#    Ambernath, Mumbai, Maharashtra  ...  \
# 0                               0  ...
# ...
