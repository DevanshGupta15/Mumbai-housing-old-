# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
sns.set_style("darkgrid")
plt.rcParams['font.size'] = 14
plt.rcParams['figure.figsize'] = (9, 5)
plt.rcParams['figure.facecolor'] = '#00000000'

# %%
df = pd.read_csv("mumbai.csv")

# %%
df.head()
# Out:
#         price                                            Address    area  \
# 0  22400000.0        Chembur, Mumbai - Harbour Line, Maharashtra   629.0
# 1  35000000.0        Chembur, Mumbai - Harbour Line, Maharashtra   974.0
# 2  31700000.0  Ghatkopar East, Mumbai - Central Line, Maharas...   968.0
# 3  18700000.0  Plot Number 283, Road Number 3, Jawahar Nagar,...   629.0
# 4  13500000.0  malad east, Malad East, Mumbai - North Mumbai,...  1090.0
#
#     latitude  longitude  Bedrooms  Bathrooms  Balcony              Status  \
# 0  19.032800  72.896357       2.0        2.0      NaN  Under Construction
# 1  19.032800  72.896357       3.0        2.0      NaN  Under Construction
# 2  19.085600  72.909277       3.0        3.0      NaN  Under Construction
# 3  19.155756  72.846862       2.0        2.0      2.0       Ready to Move
# 4  19.177555  72.849887       2.0        2.0      NaN                 NaN
#
#        neworold  parking Furnished_status  Lift               Landmarks  \
# ...

# %%
df.sample(5)
# Out:
#            price                                            Address    area  \
# 2255   4000000.0  Waliv, Mumbai - Mira Road and Beyond, Maharashtra   750.0
# 3226  14500000.0  Andheri East, Mumbai - Western Suburbs, Mahara...   825.0
# 1095   3700000.0  E2 flat no 702 e wing  hdil residency narangi ...   710.0
# 622   23000000.0  Mumbai, Santacruz East, Mumbai - Western Subur...   800.0
# 1882  45000000.0  sindhi colony Sion west mumbai maharashtra 400...  1800.0
#
#        latitude  longitude  Bedrooms  Bathrooms  Balcony         Status  \
# 2255  19.414152  72.864301       2.0        2.0      NaN  Ready to Move
# 3226  19.115491  72.872695       2.0        2.0      NaN  Ready to Move
# 1095  19.467886  72.809959       2.0        2.0      1.0  Ready to Move
# 622   19.079998  72.854502       2.0        2.0      NaN  Ready to Move
# 1882  19.048122  72.892113       3.0        2.0      NaN  Ready to Move
#
# ...

# %%
df.shape
# Out:
# (6255, 17)

# %%
df.columns
# Out:
# Index(['price', 'Address', 'area', 'latitude', 'longitude', 'Bedrooms',
#        'Bathrooms', 'Balcony', 'Status', 'neworold', 'parking',
#        'Furnished_status', 'Lift', 'Landmarks', 'type_of_building', 'desc',
#        'Price_sqft'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# price                  0
# Address                0
# area                   0
# latitude               0
# longitude              0
# Bedrooms               0
# Bathrooms              0
# Balcony             3879
# Status               481
# neworold               0
# parking             4126
# Furnished_status    2655
# Lift                4577
# Landmarks           3638
# type_of_building       0
# desc                   0
# Price_sqft             0
# dtype: int64

# %%
df.Lift.unique()
# Out:
# array([ 2.,  3.,  5.,  6.,  4., nan,  8.,  1.,  7.,  0., 10.,  9.])

# %%
df.Lift.value_counts()
# Out:
# 2.0     758
# 1.0     327
# 3.0     220
# 4.0     174
# 0.0      55
# 5.0      51
# 6.0      49
# 7.0      18
# 8.0      11
# 10.0     11
# 9.0       4
# Name: Lift, dtype: int64

# %%
df.neworold.unique()
# Out:
# array(['New Property', 'Resale'], dtype=object)

# %%
df2 = df.drop(columns=["latitude","longitude","Balcony","Furnished_status","Lift","Landmarks","desc","parking"],axis=1)

# %%
df2.shape
# Out:
# (6255, 9)

# %%
df2.head()
# Out:
#         price                                            Address    area  \
# 0  22400000.0        Chembur, Mumbai - Harbour Line, Maharashtra   629.0
# 1  35000000.0        Chembur, Mumbai - Harbour Line, Maharashtra   974.0
# 2  31700000.0  Ghatkopar East, Mumbai - Central Line, Maharas...   968.0
# 3  18700000.0  Plot Number 283, Road Number 3, Jawahar Nagar,...   629.0
# 4  13500000.0  malad east, Malad East, Mumbai - North Mumbai,...  1090.0
#
#    Bedrooms  Bathrooms              Status      neworold type_of_building  \
# 0       2.0        2.0  Under Construction  New Property             Flat
# 1       3.0        2.0  Under Construction  New Property             Flat
# 2       3.0        3.0  Under Construction  New Property             Flat
# 3       2.0        2.0       Ready to Move  New Property             Flat
# 4       2.0        2.0                 NaN  New Property             Flat
#
#      Price_sqft
# 0  35612.082671
# 1  35934.291581
# 2  32747.933884
# ...

# %%
df2.isnull().sum()
# Out:
# price                 0
# Address               0
# area                  0
# Bedrooms              0
# Bathrooms             0
# Status              481
# neworold              0
# type_of_building      0
# Price_sqft            0
# dtype: int64

# %%
df2.Status.unique()
# Out:
# array(['Under Construction', 'Ready to Move', nan], dtype=object)

# %%
df3 = df2.dropna()

# %%
df3.shape
# Out:
# (5774, 9)

# %%
df3.isnull().sum()
# Out:
# price               0
# Address             0
# area                0
# Bedrooms            0
# Bathrooms           0
# Status              0
# neworold            0
# type_of_building    0
# Price_sqft          0
# dtype: int64

# %%
df3.head()
# Out:
#         price                                            Address    area  \
# 0  22400000.0        Chembur, Mumbai - Harbour Line, Maharashtra   629.0
# 1  35000000.0        Chembur, Mumbai - Harbour Line, Maharashtra   974.0
# 2  31700000.0  Ghatkopar East, Mumbai - Central Line, Maharas...   968.0
# 3  18700000.0  Plot Number 283, Road Number 3, Jawahar Nagar,...   629.0
# 9  81000000.0  Worli, Mumbai, Worli, Mumbai - South Mumbai, M...  3260.0
#
#    Bedrooms  Bathrooms              Status      neworold type_of_building  \
# 0       2.0        2.0  Under Construction  New Property             Flat
# 1       3.0        2.0  Under Construction  New Property             Flat
# 2       3.0        3.0  Under Construction  New Property             Flat
# 3       2.0        2.0       Ready to Move  New Property             Flat
# 9       3.0        3.0       Ready to Move        Resale             Flat
#
#      Price_sqft
# 0  35612.082671
# 1  35934.291581
# 2  32747.933884
# ...

# %%
df3.Bedrooms.unique()
# Out:
# array([ 2.,  3.,  4.,  6.,  5.,  8.,  7., 10.])

# %%
df3.Bedrooms.value_counts()
# Out:
# 2.0     3777
# 3.0     1540
# 4.0      341
# 5.0       75
# 6.0       25
# 7.0        9
# 8.0        4
# 10.0       3
# Name: Bedrooms, dtype: int64

# %%
df3.Bathrooms.unique()
# Out:
# array([ 2.,  3.,  4.,  5.,  6.,  7.,  8., 10.,  0.])

# %%
df3.Bathrooms.value_counts()
# Out:
# 2.0     4011
# 3.0     1265
# 4.0      355
# 5.0      101
# 6.0       30
# 7.0        5
# 8.0        5
# 10.0       1
# 0.0        1
# Name: Bathrooms, dtype: int64

# %%
df3.Address.value_counts()
# Out:
# Mira Road, Mumbai - Mira Road and Beyond, Maharashtra                                                                                                        147
# Andheri West, Mumbai - Western Suburbs, Maharashtra                                                                                                          125
# Andheri East, Mumbai - Western Suburbs, Maharashtra                                                                                                           75
# Chembur, Mumbai - Harbour Line, Maharashtra                                                                                                                   74
# Kandivali West, Mumbai - North Mumbai, Maharashtra                                                                                                            67
#                                                                                                                                                             ...
# ...

# %%
location_counts =df3.Address.value_counts()
loacation_less_than_10 = location_counts[location_counts<=50]

# %%
print(loacation_less_than_10)
# Out:
# Kandivali East, Mumbai - North Mumbai, Maharashtra                                                                                                           46
# Goregaon West, Mumbai - North Mumbai, Maharashtra                                                                                                            40
# Ghatkopar West, Mumbai - Central Line, Maharashtra                                                                                                           39
# Bhandup West, Mumbai - Central Line, Maharashtra                                                                                                             39
# Goregaon East, Mumbai - Western Suburbs, Maharashtra                                                                                                         38
#                                                                                                                                                              ..
# ...

# %%
plt.plot(df3.Bathrooms)

# %%
df3[df3.Bathrooms>8]
# Out:
#            price                                           Address   area  \
# 2994  80000000.0  Khar East, Mumbai - Western Suburbs, Maharashtra  816.0
#
#       Bedrooms  Bathrooms         Status neworold type_of_building  \
# 2994      10.0       10.0  Ready to Move   Resale             Flat
#
#         Price_sqft
# 2994  98039.215686

# %%
df3.loc[2994]
# Out:
# price                                                     80000000.0
# Address             Khar East, Mumbai - Western Suburbs, Maharashtra
# area                                                           816.0
# Bedrooms                                                        10.0
# Bathrooms                                                       10.0
# Status                                                 Ready to Move
# neworold                                                      Resale
# type_of_building                                                Flat
# Price_sqft                                              98039.215686
# Name: 2994, dtype: object

# %%
df4 = df3.copy()

# %%
df4 = df4.drop(2994)

# %%
df4.Bathrooms.value_counts()
# Out:
# 2.0    4011
# 3.0    1265
# 4.0     355
# 5.0     101
# 6.0      30
# 7.0       5
# 8.0       5
# 0.0       1
# Name: Bathrooms, dtype: int64

# %%
df4[df4.Bathrooms==0]
# Out:
#            price                                            Address   area  \
# 3021  12000000.0  Mumbai-Western Suburbs, Kandivali West, Mumbai...  812.0
#
#       Bedrooms  Bathrooms         Status neworold type_of_building  \
# 3021       2.0        0.0  Ready to Move   Resale             Flat
#
#         Price_sqft
# 3021  14778.325123

# %%
df4[df4.Bedrooms>7]
# Out:
#             price                                            Address    area  \
# 381   130000000.0  Mysore Colony, Mumbai - Harbour Line, Maharashtra  3600.0
# 603   120000000.0  Dream land Cooperative Housing Society Mulund ...  3600.0
# 3084    9000000.0    Ulhasnagar, Mumbai - Around Mumbai, Maharashtra  1200.0
# 3289   30000000.0          Kurla, Mumbai - Central Line, Maharashtra  2100.0
# 3517   45000000.0    Ulhasnagar, Mumbai - Around Mumbai, Maharashtra  5000.0
# 3822  340000000.0  Joshi Buddhakaka Mahim Halwawala 6 Kapad Bazar...  3500.0
#
#       Bedrooms  Bathrooms         Status neworold  type_of_building  \
# 381        8.0        5.0  Ready to Move   Resale              Flat
# 603        8.0        8.0  Ready to Move   Resale              Flat
# 3084       8.0        8.0  Ready to Move   Resale  Individual House
# 3289       8.0        2.0  Ready to Move   Resale              Flat
# 3517      10.0        4.0  Ready to Move   Resale              Flat
# ...

# %%
sns.countplot(df4.neworold,data=df4)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='neworold', ylabel='count'>

# %%
sns.countplot(df4.type_of_building)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='type_of_building', ylabel='count'>

# %%
sns.countplot(df4.Status)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Status', ylabel='count'>

# %%
len(df4.Address.unique())
# Out:
# 3419

# %%
df4.Address = df4.Address.apply(lambda x : x.strip(" "))

# %%
Address_stats = df4.groupby("Address")['Address'].agg('count')

# %%
Address_stats.sort_values(ascending=False)
# Out:
# Address
# Mira Road, Mumbai - Mira Road and Beyond, Maharashtra                                                                                                                        147
# Andheri West, Mumbai - Western Suburbs, Maharashtra                                                                                                                          125
# Andheri East, Mumbai - Western Suburbs, Maharashtra                                                                                                                           75
# Chembur, Mumbai - Harbour Line, Maharashtra                                                                                                                                   74
# Kandivali West, Mumbai - North Mumbai, Maharashtra                                                                                                                            67
# ...

# %%
len(Address_stats[Address_stats<=5])
# Out:
# 3318

# %%
Address_less_than_five = Address_stats[Address_stats<=5]
Address_less_than_five
# Out:
# 3318

# %%
len(df4.Address.unique())
# Out:
# 3419

# %%
df4.Address = df4.Address.apply(lambda x : "others" if x in Address_less_than_five else x)

# %%
len(df4.Address.unique())
# Out:
# 102

# %%
df4.head(2)
# Out:
#         price                                      Address   area  Bedrooms  \
# 0  22400000.0  Chembur, Mumbai - Harbour Line, Maharashtra  629.0       2.0
# 1  35000000.0  Chembur, Mumbai - Harbour Line, Maharashtra  974.0       3.0
#
#    Bathrooms              Status      neworold type_of_building    Price_sqft
# 0        2.0  Under Construction  New Property             Flat  35612.082671
# 1        2.0  Under Construction  New Property             Flat  35934.291581

# %%
df4[df4.area/df4.Bedrooms<200].head()
# Out:
#            price                                           Address    area  \
# 957   10500000.0                                            others   660.0
# 1186  12500000.0  Dahisar East, Mumbai - North Mumbai, Maharashtra   570.0
# 2638  15000000.0   Mulund West, Mumbai - Central Line, Maharashtra   516.0
# 3084   9000000.0   Ulhasnagar, Mumbai - Around Mumbai, Maharashtra  1200.0
#
#       Bedrooms  Bathrooms         Status neworold  type_of_building  \
# 957        6.0        2.0  Ready to Move   Resale  Individual House
# 1186       3.0        2.0  Ready to Move   Resale              Flat
# 2638       3.0        3.0  Ready to Move   Resale              Flat
# 3084       8.0        8.0  Ready to Move   Resale  Individual House
#
#         Price_sqft
# 957   15909.090909
# 1186  21929.824561
# 2638  29069.767442
# 3084   7500.000000

# %%
df4.shape
# Out:
# (5773, 9)

# %%
df5 = df4[~(df4.area/df4.Bedrooms<200)]
df5.shape
# Out:
# (5769, 9)

# %%
df5.Price_sqft.describe()
# Out:
# count      5769.000000
# mean      21505.916838
# std       12801.941551
# min        1500.000000
# 25%       13750.000000
# 50%       19393.939394
# 75%       26562.500000
# max      119047.619048
# Name: Price_sqft, dtype: float64

# %%
def remove_pps_outliers(df):
    df_out = pd.DataFrame()
    for key, subdf in df.groupby('Address'):
        m = np.mean(subdf.Price_sqft)
        st = np.std(subdf.Price_sqft)
        reduced_df = subdf[(subdf.Price_sqft>(m-st)) & (subdf.Price_sqft<=(m+st))]
        df_out = pd.concat([df_out,reduced_df],ignore_index=True)
    return df_out
df6 = remove_pps_outliers(df5)
df6.shape
# Out:
# (4268, 9)

# %%
def plot_scatter_chart(df,Address):
    bhk2 = df[(df.Address==Address) & (df.Bedrooms==2)]
    bhk3 = df[(df.Address==Address) & (df.Bedrooms==3)]
    plt.rcParams['figure.figsize'] = (15,10)
    plt.scatter(bhk2.Price_sqft,bhk2.price,color='blue',label='2 BHK', s=50)
    plt.scatter(bhk3.Price_sqft,bhk3.price,marker='+', color='green',label='3 BHK', s=50)
    plt.xlabel("Total Square Feet Area")
    plt.ylabel("Price (Lakh Indian Rupees)")
    plt.title(Address)
    plt.legend()

# %%
plot_scatter_chart(df6,"Mira Road, Mumbai - Mira Road and Beyond, Maharashtra")

# %%
def remove_Bedrooms_outliers(df):
    exclude_indices = np.array([])
    for Address, Address_df in df.groupby('Address'):
        Bedrooms_stats = {}
        for Bedrooms, Bedrooms_df in Address_df.groupby('Bedrooms'):
            Bedrooms_stats[Bedrooms] = {
                'mean': np.mean(Bedrooms_df.Price_sqft),
                'std': np.std(Bedrooms_df.Price_sqft),
                'count': Bedrooms_df.shape[0]
            }
        for Bedrooms, Bedrooms_df in Address_df.groupby('Bedrooms'):
            stats = Bedrooms_stats.get(Bedrooms-1)
            if stats and stats['count']>5:
                exclude_indices = np.append(exclude_indices, Bedrooms_df[Bedrooms_df.Price_sqft<(stats['mean'])].index.values)
    return df.drop(exclude_indices,axis='index')
df7 = remove_Bedrooms_outliers(df6)
# df8 = df7.copy()
df7.shape
# Out:
# (3703, 9)

# %%
plot_scatter_chart(df6,"Mira Road, Mumbai - Mira Road and Beyond, Maharashtra")

# %%
df7[df7.Bathrooms>df7.Bedrooms+2]
# Out:
# Empty DataFrame
# Columns: [price, Address, area, Bedrooms, Bathrooms, Status, neworold, type_of_building, Price_sqft]
# Index: []

# %%
dummies = pd.get_dummies(df7.Address)
dummies.head()
# Out:
#    Agripada, Mumbai - South Mumbai, Maharashtra  \
# 0                                             1
# 1                                             1
# 2                                             1
# 3                                             1
# 5                                             0
#
#    Ambernath, Mumbai, Maharashtra  \
# 0                               0
# 1                               0
# 2                               0
# 3                               0
# 5                               1
#
#    Andheri East, Mumbai - Western Suburbs, Maharashtra  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 5                                                  0
#
#    Andheri East, Mumbai, Andheri East, Mumbai - Western Suburbs, Maharashtra  \
# 0                                                  0
# ...

# %%
df8 = pd.concat([df7,dummies.drop('others',axis='columns')],axis='columns')
df8.head()
# Out:
#         price                                       Address    area  Bedrooms  \
# 0  47500000.0  Agripada, Mumbai - South Mumbai, Maharashtra  1400.0       2.0
# 1  42500000.0  Agripada, Mumbai - South Mumbai, Maharashtra   900.0       2.0
# 2  55000000.0  Agripada, Mumbai - South Mumbai, Maharashtra  1200.0       3.0
# 3  35000000.0  Agripada, Mumbai - South Mumbai, Maharashtra   800.0       2.0
# 5   3500000.0                Ambernath, Mumbai, Maharashtra   740.0       2.0
#
#    Bathrooms         Status neworold  type_of_building    Price_sqft  \
# 0        2.0  Ready to Move   Resale              Flat  33928.571429
# 1        2.0  Ready to Move   Resale  Individual House  47222.222222
# 2        3.0  Ready to Move   Resale              Flat  45833.333333
# 3        2.0  Ready to Move   Resale              Flat  43750.000000
# 5        2.0  Ready to Move   Resale              Flat   4729.729730
#
#    Agripada, Mumbai - South Mumbai, Maharashtra  ...  \
# ...

# %%
df9= df8.drop(columns=["Address"],axis=1)

# %%
df9.head()
# Out:
#         price    area  Bedrooms  Bathrooms         Status neworold  \
# 0  47500000.0  1400.0       2.0        2.0  Ready to Move   Resale
# 1  42500000.0   900.0       2.0        2.0  Ready to Move   Resale
# 2  55000000.0  1200.0       3.0        3.0  Ready to Move   Resale
# 3  35000000.0   800.0       2.0        2.0  Ready to Move   Resale
# 5   3500000.0   740.0       2.0        2.0  Ready to Move   Resale
#
#    type_of_building    Price_sqft  \
# 0              Flat  33928.571429
# 1  Individual House  47222.222222
# 2              Flat  45833.333333
# 3              Flat  43750.000000
# 5              Flat   4729.729730
#
#    Agripada, Mumbai - South Mumbai, Maharashtra  \
# 0                                             1
# 1                                             1
# 2                                             1
# 3                                             1
# 5                                             0
#
#    Ambernath, Mumbai, Maharashtra  ...  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder
Encoder = LabelEncoder()
df9["Status"] = Encoder.fit_transform(df9["Status"])
df9["neworold"] = Encoder.fit_transform(df9["neworold"])
df9["type_of_building"] = Encoder.fit_transform(df9["type_of_building"])

# %%
df9.head()
# Out:
#         price    area  Bedrooms  Bathrooms  Status  neworold  \
# 0  47500000.0  1400.0       2.0        2.0       0         1
# 1  42500000.0   900.0       2.0        2.0       0         1
# 2  55000000.0  1200.0       3.0        3.0       0         1
# 3  35000000.0   800.0       2.0        2.0       0         1
# 5   3500000.0   740.0       2.0        2.0       0         1
#
#    type_of_building    Price_sqft  \
# 0                 0  33928.571429
# 1                 1  47222.222222
# 2                 0  45833.333333
# 3                 0  43750.000000
# 5                 0   4729.729730
#
#    Agripada, Mumbai - South Mumbai, Maharashtra  \
# 0                                             1
# 1                                             1
# 2                                             1
# 3                                             1
# 5                                             0
#
#    Ambernath, Mumbai, Maharashtra  ...  \
# 0                               0  ...
# ...

# %% [markdown]
# # BUILDING MODEL

# %%
df9.shape
# Out:
# (3703, 109)

# %%
X = df9.drop(["price"],axis=1)

# %%
X
# Out:
#         area  Bedrooms  Bathrooms  Status  neworold  type_of_building  \
# 0     1400.0       2.0        2.0       0         1                 0
# 1      900.0       2.0        2.0       0         1                 1
# 2     1200.0       3.0        3.0       0         1                 0
# 3      800.0       2.0        2.0       0         1                 0
# 5      740.0       2.0        2.0       0         1                 0
# ...      ...       ...        ...     ...       ...               ...
# 4262   550.0       2.0        2.0       0         1                 0
# 4263  1250.0       3.0        3.0       0         1                 0
# 4264   735.0       2.0        2.0       0         1                 0
# 4265   810.0       2.0        2.0       0         1                 0
# 4267   750.0       2.0        2.0       0         1                 0
#
#         Price_sqft  Agripada, Mumbai - South Mumbai, Maharashtra  \
# ...

# %%
y = df9["price"]

# %%
y
# Out:
# 0       47500000.0
# 1       42500000.0
# 2       55000000.0
# 3       35000000.0
# 5        3500000.0
#            ...
# 4262     7500000.0
# 4263    29000000.0
# 4264    24000000.0
# 4265    19500000.0
# 4267    20000000.0
# Name: price, Length: 3703, dtype: float64

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.tree import DecisionTreeRegressor

from sklearn.model_selection import ShuffleSplit

def find_best_model_using_gridsearchcv(X,y):
    algos = {
        'linear_regression' : {
            'model': LinearRegression(),
            'params': {
                'normalize': [True, False]
            }
        },
        'lasso': {
            'model': Lasso(),
            'params': {
                'alpha': [1,2],
                'selection': ['random', 'cyclic']
            }
        },
        'decision_tree': {
            'model': DecisionTreeRegressor(),
            'params': {
                'criterion' : ['mse','friedman_mse'],
                'splitter': ['best','random']
            }
        }
    }
    scores = []
    cv = ShuffleSplit(n_splits=5, test_size=0.2, random_state=0)
    for algo_name, config in algos.items():
        gs =  GridSearchCV(config['model'], config['params'], cv=cv, return_train_score=False)
        gs.fit(X,y)
        scores.append({
            'model': algo_name,
            'best_score': gs.best_score_,
            'best_params': gs.best_params_
        })

    return pd.DataFrame(scores,columns=['model','best_score','best_params'])
find_best_model_using_gridsearchcv(X,y)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LinearRegression())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
#
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=10)

# %%
from sklearn.linear_model import LinearRegression
lr_clf = LinearRegression()
lr_clf.fit(X_train,y_train)
lr_clf.score(X_test,y_test)
# Out:
# 0.9501864742730075

# %%
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import cross_val_score

cv = ShuffleSplit(n_splits=5, test_size=0.2, random_state=0)

cross_val_score(LinearRegression(), X, y, cv=cv)
# Out:
# array([-5.10462110e+12,  9.44519246e-01,  9.45108071e-01, -7.62027786e+10,
#         9.29370817e-01])

# %%
def predict_price(Address,area,Bathrooms,Bedrooms):    
    loc_index = np.where(X.columns==Address)[0][0]

    x = np.zeros(len(X.columns))
    x[0] = area
    x[1] = Bathrooms
    x[2] = Bedrooms
    if loc_index >= 0:
        x[loc_index] = 1

    return lr_clf.predict([x])[0]

# %%
predict_price('Andheri West, Mumbai - Western Suburbs, Maharashtra',1000, 2, 2)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# -1767363.274480801
